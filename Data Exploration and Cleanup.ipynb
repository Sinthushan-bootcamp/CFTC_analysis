# %%
# Import libraries and dependencies
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import datetime
import quandl as ql


# %matplotlib inline

# %% [markdown]
# # EURO CFTC Analysis
# #### (i)Clean data; (ii)Calculate 'Net Non-commercial contracts'; (iii)Calculate avg, std & z-scores; (iv)Add security data to list; (v)Plot results; (vi) Plot price chart

# %%
#Getting CFTC data from Quandl
ql.ApiConfig.api_key = 'tJdgrzhuFvMvkw--DdYw'
EUR_data = ql.get('CFTC/099741_FO_L_ALL')
EUR_data.tail()
# Out:
#             Open Interest  Noncommercial Long  Noncommercial Short  \
# Date
# 2020-06-23       648743.0            191267.0              71914.0
# 2020-06-30       643597.0            180338.0              78317.0
# 2020-07-07       646323.0            186241.0              80047.0
# 2020-07-14       667904.0            195890.0              83766.0
# 2020-07-21       710896.0            205351.0              75666.0
#
#             Noncommercial Spreads  Commercial Long  Commercial Short  \
# Date
# 2020-06-23                39122.0         329802.0          493053.0
# 2020-06-30                40708.0         330721.0          481901.0
# 2020-07-07                35223.0         331247.0          489461.0
# 2020-07-14                41318.0         333107.0          496278.0
# 2020-07-21                56487.0         346268.0          532435.0
#
#             Total Long  Total Short  Nonreportable Positions Long  \
# Date
# 2020-06-23    560192.0     604089.0                       88551.0
# 2020-06-30    551767.0     600927.0                       91829.0
# 2020-07-07    552712.0     604731.0                       93611.0
# 2020-07-14    570315.0     621362.0                       97589.0
# 2020-07-21    608105.0     664588.0                      102790.0
#
#             Nonreportable Positions Short
# Date
# 2020-06-23                        44653.0
# 2020-06-30                        42670.0
# 2020-07-07                        41592.0
# 2020-07-14                        46541.0
# 2020-07-21                        46307.0

# %%
#Clean Data
EUR_data = EUR_data.drop(columns=["Open Interest", 
                                  "Noncommercial Spreads", 
                                  "Commercial Long", 
                                  "Commercial Short", 
                                  "Total Long",
                                  "Total Short",
                                  "Nonreportable Positions Long", 
                                  "Nonreportable Positions Short"])
EUR_data.head()
# Out:
#             Noncommercial Long  Noncommercial Short
# Date
# 1999-01-05                 0.0                240.0
# 1999-01-12              1717.0               1277.0
# 1999-01-19              1256.0                283.0
# 1999-01-26              1256.0                270.0
# 1999-02-02              1930.0              12284.0

# %%
#Calculate Net Data
EUR_data["Net Noncommercial Futures/Options"] = EUR_data["Noncommercial Long"] - EUR_data["Noncommercial Short"]
EUR_data.tail()
# Out:
#             Noncommercial Long  Noncommercial Short  \
# Date
# 2020-06-23            191267.0              71914.0
# 2020-06-30            180338.0              78317.0
# 2020-07-07            186241.0              80047.0
# 2020-07-14            195890.0              83766.0
# 2020-07-21            205351.0              75666.0
#
#             Net Noncommercial Futures/Options
# Date
# 2020-06-23                           119353.0
# 2020-06-30                           102021.0
# 2020-07-07                           106194.0
# 2020-07-14                           112124.0
# 2020-07-21                           129685.0

# %%
#Calculate mean, std and Z-Score
Average = EUR_data["Net Noncommercial Futures/Options"].mean()
x = np.array(EUR_data["Net Noncommercial Futures/Options"])
std = x.std()

z_score_historical_eur = ((EUR_data["Net Noncommercial Futures/Options"][-1]) - Average)/std
z_score_historical_eur
# Out:
# 2.054733847481858

# %%
#Create list to display data

EUR_list = ["Currency", "EUR", EUR_data["Net Noncommercial Futures/Options"][-1], Average, std, z_score_historical_eur]
print(EUR_list)
# Out:
# ['Currency', 'EUR', 129685.0, -8889.348444444444, 67441.5076260469, 2.054733847481858]

# %%
#Plot EUR CFTC data
def create_plot(x_axis_data, y_axis_data, asset_name):
    x = EUR_data.index
    y = EUR_data["Net Noncommercial Futures/Options"]
    std_positive = (Average + std)
    std_negative = (Average - std)

    plt.subplots(figsize=(20,10))
    plt.plot(x,y, label="Net positions")
    plt.axhline(y=Average,color="grey",linestyle="--", label="mean")
    plt.axhline(y=std_positive, color="green", linestyle="--",label="1STD")
    plt.axhline(y=std_negative, color="red", linestyle="--", label="1STD")
    plt.legend()
    plt.xlabel("Date")
    plt.title(f"{asset_name}: CFTC Net Noncommercial Futures & Options", fontdict={'fontweight':'bold', 'fontsize':'22'})
    plt.show()
#create_plot(EUR_data["Net Noncommercial Futures/Options"])
create_plot(EUR_data.index, EUR_data["Net Noncommercial Futures/Options"], "EUR")

# %%
##Plot EUR CFTC data last 3 years
def create_plot(data):
    x = EUR_data.index[-156:]
    y = EUR_data["Net Noncommercial Futures/Options"][-156:]
    std_positive = (Average + std)
    std_negative = (Average - std)

    plt.subplots(figsize=(20,10))
    plt.plot(x,y, label="Net positions")
    plt.axhline(y=Average,color="grey",linestyle="--", label="mean")
    plt.axhline(y=std_positive, color="green", linestyle="--",label="1STD")
    plt.axhline(y=std_negative, color="red", linestyle="--", label="1STD")
    plt.legend()
    plt.xlabel("Date")
    plt.title(f"EUR: CFTC Net Noncommercial Futures & Options", fontdict={'fontweight':'bold', 'fontsize':'22'})
    plt.savefig(f'EURcftc.png', bbox_inches="tight")
    plt.show()
    
create_plot(EUR_data["Net Noncommercial Futures/Options"][-156:])

# %%
# Plotting Price action
def create_plot(tickersymbol):
    ticker_data = yf.Ticker(tickersymbol)
    today = datetime.datetime.today().isoformat()
    
    ticker_df = ticker_data.history(period='1d', start='2017-07-15', end=today[:10])
    plt.subplots(figsize=(20,10))
    plt.plot(ticker_df["Close"], label=ticker_data.info['shortName'])
    plt.xlabel("Date")
    plt.ylabel("Closing Price")
    plt.title(f"{ticker_data.info['shortName']} closing price")
    plt.savefig(f'EURprice.png', bbox_inches="tight")
    
create_plot('FXE')

# %% [markdown]
# ## CAD: CFTC Analysis
# #### (i) Clean data; (ii) Calculate 'Net Non-commercial contracts'; (iii) Calculate avg, std & z-scores; (iv) Add security data to list; (v) Plot results; (vi) Plot price chart

# %%
#Getting CFTC data from Quandl
CAD_data = ql.get('CFTC/090741_FO_L_ALL')
CAD_data.tail()
# Out:
#             Open Interest  Noncommercial Long  Noncommercial Short  \
# Date
# 2020-06-16       141969.0             19620.0              45542.0
# 2020-06-23       120862.0             22806.0              43525.0
# 2020-06-30       133791.0             29252.0              48578.0
# 2020-07-07       132272.0             32065.0              48564.0
# 2020-07-14       159324.0             27573.0              47227.0
#
#             Noncommercial Spreads  Commercial Long  Commercial Short  \
# Date
# 2020-06-16                 9154.0          86078.0           61014.0
# 2020-06-23                 7698.0          62675.0           44634.0
# 2020-06-30                 6841.0          70926.0           53265.0
# 2020-07-07                 5444.0          68907.0           51408.0
# 2020-07-14                 5586.0          99548.0           80406.0
#
#             Total Long  Total Short  Nonreportable Positions Long  \
# Date
# 2020-06-16    114852.0     115710.0                       27117.0
# 2020-06-23     93178.0      95857.0                       27684.0
# 2020-06-30    107018.0     108684.0                       26773.0
# 2020-07-07    106416.0     105416.0                       25856.0
# 2020-07-14    132708.0     133219.0                       26617.0
#
#             Nonreportable Positions Short
# Date
# 2020-06-16                        26259.0
# 2020-06-23                        25005.0
# 2020-06-30                        25107.0
# 2020-07-07                        26856.0
# 2020-07-14                        26105.0

# %%
#Clean Data
CAD_data = CAD_data.drop(columns=["Open Interest", 
                                  "Noncommercial Spreads", 
                                  "Commercial Long", 
                                  "Commercial Short", 
                                  "Total Long",
                                  "Total Short",
                                  "Nonreportable Positions Long", 
                                  "Nonreportable Positions Short"])
CAD_data.head()
# Out:
#             Noncommercial Long  Noncommercial Short
# Date
# 1995-03-21              3967.0               3208.0
# 1995-03-28              3824.0               2398.0
# 1995-04-04              7433.0               1614.0
# 1995-04-11             16619.0               2242.0
# 1995-04-18             17359.0                847.0

# %%
#Calculate Net Data
CAD_data["Net Noncommercial Futures/Options"] = CAD_data["Noncommercial Long"] - CAD_data["Noncommercial Short"]
CAD_data.tail()
# Out:
#             Noncommercial Long  Noncommercial Short  \
# Date
# 2020-06-16             19620.0              45542.0
# 2020-06-23             22806.0              43525.0
# 2020-06-30             29252.0              48578.0
# 2020-07-07             32065.0              48564.0
# 2020-07-14             27573.0              47227.0
#
#             Net Noncommercial Futures/Options
# Date
# 2020-06-16                           -25922.0
# 2020-06-23                           -20719.0
# 2020-06-30                           -19326.0
# 2020-07-07                           -16499.0
# 2020-07-14                           -19654.0

# %%
#Calculate mean and std
Average_cad = CAD_data["Net Noncommercial Futures/Options"].mean()
x = np.array(CAD_data["Net Noncommercial Futures/Options"])
std_cad = x.std()

z_score_historical_cad = ((CAD_data["Net Noncommercial Futures/Options"][-1]) - Average_cad)/std_cad
z_score_historical_cad
# Out:
# -0.7112025088351145

# %%
#Create list to display data

CAD_list = ["Currency", "CAD", CAD_data["Net Noncommercial Futures/Options"][-1], Average_cad, std_cad, z_score_historical_cad]
print(CAD_list)
# Out:
# ['Currency', 'CAD', -19654.0, 2841.4046898638426, 31630.097490388896, -0.7112025088351145]

# %%
#Plot CAD CFTC data
def create_plot(data):
    x = CAD_data.index
    y = CAD_data["Net Noncommercial Futures/Options"]
    std_positive = (Average_cad + std_cad)
    std_negative = (Average_cad - std_cad)

    plt.subplots(figsize=(20,10))
    plt.plot(x,y, label="Net positions")
    plt.axhline(y=Average_cad,color="grey",linestyle="--", label="Mean")
    plt.axhline(y=std_positive, color="green", linestyle="--", label="1STD")
    plt.axhline(y=std_negative, color="red", linestyle="--", label="1STD")
    plt.legend()
    plt.xlabel("Date")
    plt.title(f"CAD: CFTC Net Noncommercial Futures & Options", fontdict={'fontweight':'bold', 'fontsize':'22'})
    plt.show()
create_plot(CAD_data["Net Noncommercial Futures/Options"][-252])

# %%
# Plot CAD CFTC data last 3 years
def create_plot(data):
    x = CAD_data.index[-156:]
    y = CAD_data["Net Noncommercial Futures/Options"][-156:]
    std_positive = (Average_cad + std_cad)
    std_negative = (Average_cad - std_cad)


    plt.subplots(figsize=(20,10))
    plt.plot(x,y, label="Net positions")
    plt.axhline(y=Average_cad,color="grey",linestyle="--", label="mean")
    plt.axhline(y=std_positive, color="green", linestyle="--",label="1STD")
    plt.axhline(y=std_negative, color="red", linestyle="--", label="1STD")
    plt.legend()
    plt.xlabel("Date")
    plt.title(f"CAD: CFTC Net Noncommercial Futures & Options", fontdict={'fontweight':'bold', 'fontsize':'22'})
    plt.show()
create_plot(CAD_data["Net Noncommercial Futures/Options"][-156:])

# %%
# Plotting Price action
def create_plot(tickersymbol):
    ticker_data = yf.Ticker(tickersymbol)
    today = datetime.datetime.today().isoformat()
    
    ticker_df = ticker_data.history(period='1d', start='2017-07-15', end=today[:10])
    plt.subplots(figsize=(20,10))
    plt.plot(ticker_df["Close"], label=ticker_data.info['shortName'])
    plt.xlabel("Date")
    plt.ylabel("Closing Price")
    plt.title(f"{ticker_data.info['shortName']} closing price")
    
create_plot('FXC')

# %% [markdown]
# # USD Analysis
# #### (i) Clean data; (ii) Calculate 'Net Non-commercial contracts'; (iii) Calculate avg, std & z-scores; (iv) Add security data to list; (v) Plot results; (vi) Plot price chart

# %%
#Getting CFTC data from Quandl
USD_data = ql.get('CFTC/098662_FO_L_ALL')
USD_data.tail()
# Out:
#             Open Interest  Noncommercial Long  Noncommercial Short  \
# Date
# 2020-06-16        19897.0             10802.0              16140.0
# 2020-06-23        21629.0             11661.0              16967.0
# 2020-06-30        19470.0              9823.0              14787.0
# 2020-07-07        22898.0             12150.0              17075.0
# 2020-07-14        23531.0             12139.0              17162.0
#
#             Noncommercial Spreads  Commercial Long  Commercial Short  \
# Date
# 2020-06-16                  946.0           5625.0             483.0
# 2020-06-23                 1094.0           6662.0             857.0
# 2020-06-30                 1190.0           5938.0             940.0
# 2020-07-07                 1979.0           6316.0             857.0
# 2020-07-14                 2220.0           6720.0            1093.0
#
#             Total Long  Total Short  Nonreportable Positions Long  \
# Date
# 2020-06-16     17374.0      17570.0                        2524.0
# 2020-06-23     19417.0      18918.0                        2212.0
# 2020-06-30     16951.0      16918.0                        2519.0
# 2020-07-07     20445.0      19911.0                        2452.0
# 2020-07-14     21078.0      20474.0                        2452.0
#
#             Nonreportable Positions Short
# Date
# 2020-06-16                         2328.0
# 2020-06-23                         2711.0
# 2020-06-30                         2552.0
# 2020-07-07                         2987.0
# 2020-07-14                         3056.0

# %%
#Clean Data
USD_data = USD_data.drop(columns=["Open Interest", 
                                  "Noncommercial Spreads", 
                                  "Commercial Long", 
                                  "Commercial Short", 
                                  "Total Long",
                                  "Total Short",
                                  "Nonreportable Positions Long", 
                                  "Nonreportable Positions Short"])
USD_data.head()
# Out:
#             Noncommercial Long  Noncommercial Short
# Date
# 1995-03-21              2227.0               2334.0
# 1995-03-28              2803.0               3635.0
# 1995-04-04              3061.0               4332.0
# 1995-04-18              4955.0               5570.0
# 1995-04-25              2847.0               3327.0

# %%
#Calculate Net Data
USD_data["Net Noncommercial Futures/Options"] = USD_data["Noncommercial Long"] - USD_data["Noncommercial Short"]
USD_data.tail()
# Out:
#             Noncommercial Long  Noncommercial Short  \
# Date
# 2020-06-16             10802.0              16140.0
# 2020-06-23             11661.0              16967.0
# 2020-06-30              9823.0              14787.0
# 2020-07-07             12150.0              17075.0
# 2020-07-14             12139.0              17162.0
#
#             Net Noncommercial Futures/Options
# Date
# 2020-06-16                            -5338.0
# 2020-06-23                            -5306.0
# 2020-06-30                            -4964.0
# 2020-07-07                            -4925.0
# 2020-07-14                            -5023.0

# %%
#Calculate mean and std
Average_usd = USD_data["Net Noncommercial Futures/Options"].mean()
x = np.array(USD_data["Net Noncommercial Futures/Options"])
std_usd = x.std()


z_score_historical_usd = ((USD_data["Net Noncommercial Futures/Options"][-1]) - Average_usd)/std_usd
z_score_historical_usd
# Out:
# -0.7999520680547448

# %%
#Create list to display data

USD_list = ["Currency", "USD", USD_data["Net Noncommercial Futures/Options"][-1], Average_usd, std_usd, z_score_historical_usd]
print(USD_list)
# Out:
# ['Currency', 'USD', -5023.0, 10164.389992057188, 18985.37499751527, -0.7999520680547448]

# %%
#Plot USD CFTC data
def create_plot(data):
    x = USD_data.index
    y = USD_data["Net Noncommercial Futures/Options"]
    std_positive = (Average_usd + std_usd)
    std_negative = (Average_usd - std_usd)

    plt.subplots(figsize=(20,10))
    plt.plot(x,y, label="Net positions")
    plt.axhline(y=Average_usd,color="grey",linestyle="--", label="mean")
    plt.axhline(y=std_positive, color="green", linestyle="--",label="1STD")
    plt.axhline(y=std_negative, color="red", linestyle="--", label="1STD")
    plt.legend()
    plt.xlabel("Date")
    plt.title(f"USD: CFTC Net Noncommercial Futures & Options", fontdict={'fontweight':'bold', 'fontsize':'22'})
    plt.show()
create_plot(USD_data["Net Noncommercial Futures/Options"])

# %%
##Plot USD CFTC data last 3 years
def create_plot(data):
    x = USD_data.index[-156:]
    y = USD_data["Net Noncommercial Futures/Options"][-156:]
    std_positive = (Average_usd + std_usd)
    std_negative = (Average_usd - std_usd)

    plt.subplots(figsize=(20,10))
    plt.plot(x,y, label="Net positions")
    plt.axhline(y=Average_usd,color="grey",linestyle="--", label="mean")
    plt.axhline(y=std_positive, color="green", linestyle="--",label="1STD")
    plt.axhline(y=std_negative, color="red", linestyle="--", label="1STD")
    plt.legend()
    plt.xlabel("Date")
    plt.title(f"USD: CFTC Net Noncommercial Futures & Options", fontdict={'fontweight':'bold', 'fontsize':'22'})
    plt.show()
create_plot(USD_data["Net Noncommercial Futures/Options"][-156:])

# %%
# Plotting Price action
def create_plot(tickersymbol):
    ticker_data = yf.Ticker(tickersymbol)
    today = datetime.datetime.today().isoformat()
    
    ticker_df = ticker_data.history(period='1d', start='2019-07-15', end=today[:10])
    plt.subplots(figsize=(20,10))
    plt.plot(ticker_df["Close"], label=ticker_data.info['shortName'])
    plt.xlabel("Date")
    plt.ylabel("Closing Price")
    plt.title(f"{ticker_data.info['shortName']} closing price")
    
create_plot('UUP')

# %% [markdown]
# # AUD Analysis
# #### (i) Clean data; (ii) Calculate 'Net Non-commercial contracts'; (iii) Calculate avg, std & z-scores; (iv) Add security data to list; (v) Plot results; (vi) Plot price chart

# %%
#Getting CFTC data from Quandl
AUD_data = ql.get('CFTC/232741_FO_L_ALL')
AUD_data.tail()
# Out:
#             Open Interest  Noncommercial Long  Noncommercial Short  \
# Date
# 2020-06-23       112601.0             37270.0              39574.0
# 2020-06-30       117655.0             41247.0              41951.0
# 2020-07-07       117499.0             44663.0              45556.0
# 2020-07-14       120973.0             44795.0              41345.0
# 2020-07-21       126590.0             41707.0              42100.0
#
#             Noncommercial Spreads  Commercial Long  Commercial Short  \
# Date
# 2020-06-23                10375.0          44088.0           41309.0
# 2020-06-30                 9493.0          46389.0           42891.0
# 2020-07-07                 6620.0          42641.0           45205.0
# 2020-07-14                 7400.0          46277.0           50424.0
# 2020-07-21                 9145.0          49443.0           50274.0
#
#             Total Long  Total Short  Nonreportable Positions Long  \
# Date
# 2020-06-23     91732.0      91258.0                       20869.0
# 2020-06-30     97128.0      94335.0                       20527.0
# 2020-07-07     93925.0      97381.0                       23574.0
# 2020-07-14     98471.0      99169.0                       22502.0
# 2020-07-21    100295.0     101519.0                       26295.0
#
#             Nonreportable Positions Short
# Date
# 2020-06-23                        21343.0
# 2020-06-30                        23321.0
# 2020-07-07                        20118.0
# 2020-07-14                        21805.0
# 2020-07-21                        25071.0

# %%
#Clean Data
AUD_data = AUD_data.drop(columns=["Open Interest", 
                                  "Noncommercial Spreads", 
                                  "Commercial Long", 
                                  "Commercial Short", 
                                  "Total Long",
                                  "Total Short",
                                  "Nonreportable Positions Long", 
                                  "Nonreportable Positions Short"])
AUD_data.head()
# Out:
#             Noncommercial Long  Noncommercial Short
# Date
# 1995-03-21                 0.0               3962.0
# 1995-03-28                 0.0               3961.0
# 1995-04-04                 0.0               2702.0
# 1995-04-11                 0.0               1593.0
# 1995-04-18                 0.0               1509.0

# %%
#Calculate Net Data
AUD_data["Net Noncommercial Futures/Options"] = AUD_data["Noncommercial Long"] - AUD_data["Noncommercial Short"]
AUD_data.tail()
# Out:
#             Noncommercial Long  Noncommercial Short  \
# Date
# 2020-06-23             37270.0              39574.0
# 2020-06-30             41247.0              41951.0
# 2020-07-07             44663.0              45556.0
# 2020-07-14             44795.0              41345.0
# 2020-07-21             41707.0              42100.0
#
#             Net Noncommercial Futures/Options
# Date
# 2020-06-23                            -2304.0
# 2020-06-30                             -704.0
# 2020-07-07                             -893.0
# 2020-07-14                             3450.0
# 2020-07-21                             -393.0

# %%
#Calculate mean and std
Average_aud = AUD_data["Net Noncommercial Futures/Options"][-52:].mean()
x = np.array(AUD_data["Net Noncommercial Futures/Options"][-52:])
std_aud = x.std()


z_score_historical_aud = ((AUD_data["Net Noncommercial Futures/Options"][-1]) - Average_aud)/std_aud
std_aud
# Out:
# 16430.52583354501

# %%
#Create list to display data

AUD_list = ["Currency", "AUD", AUD_data["Net Noncommercial Futures/Options"][-1], Average_aud, std_aud, z_score_historical_aud]
print(AUD_list)
# Out:
# ['Currency', 'AUD', -393.0, -37524.78846153846, 16430.52583354501, 2.259926969940864]

# %%
#Plot AUD CFTC data
def create_plot(data):
    x = AUD_data.index
    y = AUD_data["Net Noncommercial Futures/Options"]
    std_positive = (Average_aud + std_aud)
    std_negative = (Average_aud - std_aud)

    plt.subplots(figsize=(20,10))
    plt.plot(x,y, label="Net positions")
    plt.axhline(y=Average_aud,color="grey",linestyle="--", label="mean")
    plt.axhline(y=std_positive, color="green", linestyle="--",label="1STD")
    plt.axhline(y=std_negative, color="red", linestyle="--", label="1STD")
    plt.legend()
    plt.xlabel("Date")
    plt.title(f"AUD: CFTC Net Noncommercial Futures & Options", fontdict={'fontweight':'bold', 'fontsize':'22'})
    plt.show()
create_plot(AUD_data["Net Noncommercial Futures/Options"])

# %%
##Plot AUD CFTC data last 3 years
def create_plot(data):
    x = AUD_data.index[-156:]
    y = AUD_data["Net Noncommercial Futures/Options"][-156:]
    std_positive = (Average_aud + std_aud)
    std_negative = (Average_aud - std_aud)

    plt.subplots(figsize=(20,10))
    plt.plot(x,y, label="Net positions")
    plt.axhline(y=Average_aud,color="grey",linestyle="--", label="mean")
    plt.axhline(y=std_positive, color="green", linestyle="--",label="1STD")
    plt.axhline(y=std_negative, color="red", linestyle="--", label="1STD")
    plt.legend()
    plt.xlabel("Date")
    plt.title(f"AUD: CFTC Net Noncommercial Futures & Options", fontdict={'fontweight':'bold', 'fontsize':'22'})
    plt.show()
create_plot(AUD_data["Net Noncommercial Futures/Options"][-156:])

# %%
# Plotting Price action
def create_plot(tickersymbol):
    ticker_data = yf.Ticker(tickersymbol)
    today = datetime.datetime.today().isoformat()
    
    ticker_df = ticker_data.history(period='1d', start='2019-07-15', end=today[:10])
    plt.subplots(figsize=(20,10))
    plt.plot(ticker_df["Close"], label=ticker_data.info['shortName'])
    plt.xlabel("Date")
    plt.ylabel("Closing Price")
    plt.title(f"{ticker_data.info['shortName']} closing price")
    
create_plot('FXA')

# %% [markdown]
# # Create a dataframe and then exporting to Excel

# %%
#Create df

df = pd.DataFrame([EUR_list, CAD_list, USD_list], columns =['Asset_Class','Security',
                                                  'Latest_position',
                                                  'Average_position',
                                                  'STD',
                                                  'Z-score'], dtype = float) 

df
# Out:
#   Asset_Class Security  Latest_position  Average_position           STD  \
# 0    Currency      EUR         112124.0      -9012.635231  67344.665312
# 1    Currency      CAD         -19654.0       2841.404690  31630.097490
# 2    Currency      USD          -5023.0      10164.389992  18985.374998
#
#     Z-score
# 0  1.798756
# 1 -0.711203
# 2 -0.799952

# %%
#Conditional formatting
overbought_threshold = 1.5
oversold_threshold = -1.5

df_styled = df.style\
    .applymap(lambda x: 'background-color: %s' % 'red' if x > overbought_threshold or x < oversold_threshold else 'background_color: %s' % 'green', subset=['Z-score'])
   
df_styled
# Out:
# <style  type="text/css" >
#     #T_94285c4a_cd19_11ea_865d_c8348e32f095row0_col5 {
#             background-color:  red;
#         }    #T_94285c4a_cd19_11ea_865d_c8348e32f095row1_col5 {
#             background_color:  green;
#         }    #T_94285c4a_cd19_11ea_865d_c8348e32f095row2_col5 {
#             background_color:  green;
#         }</style><table id="T_94285c4a_cd19_11ea_865d_c8348e32f095" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Asset_Class</th>        <th class="col_heading level0 col1" >Security</th>        <th class="col_heading level0 col2" >Latest_position</th>        <th class="col_heading level0 col3" >Average_position</th>        <th class="col_heading level0 col4" >STD</th>        <th class="col_heading level0 col5" >Z-score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_94285c4a_cd19_11ea_865d_c8348e32f095level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_94285c4a_cd19_11ea_865d_c8348e32f095row0_col0" class="data row0 col0" >Currency</td>
#                         <td id="T_94285c4a_cd19_11ea_865d_c8348e32f095row0_col1" class="data row0 col1" >EUR</td>
#                         <td id="T_94285c4a_cd19_11ea_865d_c8348e32f095row0_col2" class="data row0 col2" >112124.000000</td>
#                         <td id="T_94285c4a_cd19_11ea_865d_c8348e32f095row0_col3" class="data row0 col3" >-9012.635231</td>
#                         <td id="T_94285c4a_cd19_11ea_865d_c8348e32f095row0_col4" class="data row0 col4" >67344.665312</td>
#                         <td id="T_94285c4a_cd19_11ea_865d_c8348e32f095row0_col5" class="data row0 col5" >1.798756</td>
#             </tr>
#             <tr>
#                         <th id="T_94285c4a_cd19_11ea_865d_c8348e32f095level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_94285c4a_cd19_11ea_865d_c8348e32f095row1_col0" class="data row1 col0" >Currency</td>
#                         <td id="T_94285c4a_cd19_11ea_865d_c8348e32f095row1_col1" class="data row1 col1" >CAD</td>
#                         <td id="T_94285c4a_cd19_11ea_865d_c8348e32f095row1_col2" class="data row1 col2" >-19654.000000</td>
#                         <td id="T_94285c4a_cd19_11ea_865d_c8348e32f095row1_col3" class="data row1 col3" >2841.404690</td>
#                         <td id="T_94285c4a_cd19_11ea_865d_c8348e32f095row1_col4" class="data row1 col4" >31630.097490</td>
#                         <td id="T_94285c4a_cd19_11ea_865d_c8348e32f095row1_col5" class="data row1 col5" >-0.711203</td>
#             </tr>
#             <tr>
#                         <th id="T_94285c4a_cd19_11ea_865d_c8348e32f095level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_94285c4a_cd19_11ea_865d_c8348e32f095row2_col0" class="data row2 col0" >Currency</td>
#                         <td id="T_94285c4a_cd19_11ea_865d_c8348e32f095row2_col1" class="data row2 col1" >USD</td>
#                         <td id="T_94285c4a_cd19_11ea_865d_c8348e32f095row2_col2" class="data row2 col2" >-5023.000000</td>
#                         <td id="T_94285c4a_cd19_11ea_865d_c8348e32f095row2_col3" class="data row2 col3" >10164.389992</td>
#                         <td id="T_94285c4a_cd19_11ea_865d_c8348e32f095row2_col4" class="data row2 col4" >18985.374998</td>
#                         <td id="T_94285c4a_cd19_11ea_865d_c8348e32f095row2_col5" class="data row2 col5" >-0.799952</td>
#             </tr>
#     </tbody></table>

# %%
import xlsxwriter

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('cftc_test.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df_styled.to_excel(writer, sheet_name='Sheet1', float_format='%.2f')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
def zscore(x, window):
    r = x.rolling(window=window)
    m = r.mean().shift(1)
    s = r.std(ddof=0).shift(1)
    z = (x-m)/s
    return z

EUR_data['Z_score_3yr'] = zscore(EUR_data.loc[:,'Net Noncommercial Futures/Options'], 52*3)
EUR_data['Z_score_3yr'].plot()
